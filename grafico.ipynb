# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\PICHAU\Documents\Programação\Santandercoders\archive\Book_Details.csv')

# %%
eixo_x = df['genres'].value_counts().keys()
eixo_y = df['genres'].value_counts().values

# %%
plt.bar(eixo_x,eixo_y)

plt.title('Gênero de livros')

plt.xticks(rotation=45)

plt.show()
